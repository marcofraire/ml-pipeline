# 31   Fire & Blood by George R. R. Martin Paperback ...     8.00        0
# 32    A Game Of Thrones: Song Of Ice And Fire (Sealed)    10.00        0
# 33   A Game Of Thrones Leather-Cloth Boxed Set: A G...    50.00        0
# 35   Game of Thrones Song of Ice and Fire PB/Hardco...   109.99        0
# 36   A Game of Thrones 2002 LARGE FORMAT 1st Print ...    30.00        0
# 37   SIGNED NOTE A Game of Thrones by George R. R. ...   500.00        0
# 38   A Game of Thrones CCG: Iron Throne Edition Boo...    51.95        0
# 39   A Clash of Kings by George R. R. Martin (1999,...    52.00        0
# 40   A Game of Thrones: The Card Game - A Song Of S...    11.99        0
# 41   George R.R. Martin: A GAME OF THRONES Bantam H...   405.00        0
# 42   George R.R. Martin: A GAME OF THRONES **HC/DJ ...    90.00        0
# 48   Fire and Blood: 300 Years Before A Game of Thr...    13.54        0
# 50   Fire and Blood: 300 Years Before A Game of Thr...   138.12        0
# 56   A Game of Thrones LCG (1st Edition): Targaryen...    19.95        0
# 58   New Game Of Thrones Barnes & Noble EXCLUSIVE e...    14.99        0
# 62   A Game of Thrones The Card Game 2nd Edition Hu...   600.00        0
# 64   George R.R. Martin: A GAME OF THRONES **HC/DJ ...   245.50        0
# 67   A Feast For Crows Uncirculated Jacket SIGNED G...  1400.00        0
# 70   A Game of Thrones LCG (1st Edition): The Winds...    20.00        0
# 76   1st Ed - A GAME of THRONES George R.R. Martin ...   185.00        0
# 77   A Game of Thrones ~ GEORGE R. R. MARTIN ~ Firs...   495.00        0
# 82   A Game Of Thrones: Song Of Ice And Fire (B & N...    18.99        0
# 89   A GAME OF THRONES *SIGNED* 1ST/1ST First Editi...   699.00        0
# 91   A Game of Thrones (A Song of Ice and Fire) by ...    18.81        0
# 100  1st Ed - A GAME of THRONES George R.R. Martin ...   419.30        0
# 103  Game of Thrones The Graphic Novels Volumes 1-4...    89.95        0
# 105  A Game Of Thrones-George R. R. Martin-FIRST ED...    51.00        0
# 116  George R.R. Martin: A GAME OF THRONES **HC/DJ ...   281.66        0
# 117               A Game of Thrones Signed 1st Edition   480.00        0
# 121  A Game of Thrones by George R. R. Martin 1st U...   550.00        0
# 122  A Game of Thrones LCG (1st Edition): The Blue ...    10.00        0
# 129  A Game of Thrones ~ GEORGE R. R. MARTIN ~ Sign...  1500.00        0
# 131  A Game of Thrones (A Song of Ice and Fire) Geo...    39.90        0
# 139  A Game of Thrones LCG (1st Edition): Return of...    10.00        0
# 146  George RR Martin A Game of Thrones Signed True...   399.00        0
# 153  George RR Martin - Signed - A  Game of Thrones...   475.00        0
#
#                       seller seller_rating  seller_sales      sale_data  \
# 2                   beli9460             0         0.000   Apr 28, 2024
# 3               retro-cowboy           734         1.000   Apr 28, 2024
# 4              amandchave_15           756         0.991   Apr 28, 2024
# 5      nostalgiatradingcards          1108         0.998   Apr 26, 2024
# 6                 chribe8221           597         1.000   Apr 26, 2024
# 7                   spike718          2537         1.000   Apr 26, 2024
# 8                 moonbayart           442         1.000   Apr 26, 2024
# 10                   tleonel         10008         0.998   Apr 24, 2024
# 11       keepsakekeyholders1           628         0.998   Apr 23, 2024
# 12           autographedbook          5785         1.000   Apr 22, 2024
# 13           worldofbooksusa       1082051         0.949   Apr 22, 2024
# 14                 larmojovi          1100         1.000   Apr 21, 2024
# 16                 2211brent           911         1.000   Apr 21, 2024
# 17                   bookbid          5657         1.000   Apr 20, 2024
# 18                sages-shop            42         0.938   Apr 20, 2024
# 20           rautioresalellc           724         1.000   Apr 20, 2024
# 21                marioplace         80349         0.990   Sep 26, 2023
# 22                 spock_105            96         1.000   Apr 18, 2024
# 23                  haboli53            29         1.000   Apr 17, 2024
# 24   juliesmagicmarketbazaar           727         0.996   Oct 19, 2023
# 26                 just1gail           246         0.971   Apr 15, 2024
# 27                  adrvan29           592         0.986   Apr 14, 2024
# 29           worldofbooksusa       1082051         0.949   Apr 14, 2024
# 30                 lagarm-35            43         1.000   Apr 14, 2024
# 31                  762baker          1387         0.996   Apr 13, 2024
# 32         marybelstreasures            86         0.968   Apr 12, 2024
# 33             ssmicheal2024             5         1.000   Apr 12, 2024
# 35      tetheredheartsdesign           111         1.000   Apr 10, 2024
# 36          flippinout_sales           369         0.978   Apr 10, 2024
# 37           extrashelfspace           684         1.000   Apr 10, 2024
# 38     nostalgiatradingcards          1108         0.998   Apr 10, 2024
# 39              alienmotives         14052         1.000    Apr 9, 2024
# 40                rydrretail           372         1.000    Apr 9, 2024
# 41      myclosetofrandomness           205         0.989    Apr 7, 2024
# 42             marvonbruen_0            74         1.000    Apr 6, 2024
# 48           worldofbooksusa       1082051         0.949    Apr 3, 2024
# 50           worldofbooksusa       1082051         0.949    Apr 3, 2024
# 56                gamezenter           151         0.933   Mar 30, 2024
# 58                   twoes95           110         1.000   Mar 30, 2024
# 62              cthulhucards           752         1.000   Mar 29, 2024
# 64                  towhsl-0            92         1.000   Mar 28, 2024
# 67            go-bad-chicken          1388         1.000   Mar 27, 2024
# 70                gamezenter           151         0.933   Mar 27, 2024
# 76                 vacantjay           766         0.997   Mar 20, 2024
# 77                   krakow1          9530         0.989   Mar 19, 2024
# 82            kimmiebird0912         11264         1.000   Mar 16, 2024
# 89       martinsscifisociety           183         1.000   Mar 11, 2024
# 91           worldofbooksusa       1082051         0.949    Mar 9, 2024
# 100       the_vintage_viking          1134         1.000    Mar 6, 2024
# 103                 clarkfan         31734         1.000    Mar 6, 2024
# 105            coolpapasmurf            98         0.963    Mar 5, 2024
# 116                 imagerie          2300         1.000   Feb 25, 2024
# 117           atxcollections           409         0.995   Feb 25, 2024
# 121               jerr_pasil           378         1.000   Feb 23, 2024
# 122               gamezenter           151         0.933   Feb 22, 2024
# 129        burnsiderarebooks          2980         1.000   Feb 16, 2024
# 131         dunkin_bookstore         33955         0.989   Feb 15, 2024
# 139               gamezenter           151         0.933   Feb 12, 2024
# 146               chribe8221           597         1.000   Feb 10, 2024
# 153     cornerstoneusedbooks          2050         1.000    Feb 7, 2024
#
#                 country            img_id edition_id
# 2    from United States  UG8AAOSwHtpmCiq7          1
# 3    from United States  cA0AAOSwsJNl4~Jk          1
# 4    from United States  2NQAAOSwE7Jl22MN          1
# 5    from United States  cY4AAOSwym1lg0mQ          1
# 6    from United States  VIYAAOSwk3Blg5UF          1
# 7    from United States  4e0AAOSwb~tl3x9E          1
# 8    from United States  h78AAOSw5aJmFEt4          1
# 10   from United States  iaYAAOSw-dlmFUT~          1
# 11   from United States  proAAOSwtklmG~PC          1
# 12   from United States  lGcAAOSwx2Vk16wp          1
# 13   from United States  QKsAAOSw5s1fY1fE          1
# 14   from United States  naUAAOSwe7NmAHM3          1
# 16   from United States  tnUAAOSwXNdmJENs          1
# 17   from United States  LoYAAOSwqdBmFWGa          1
# 18   from United States  tugAAOSw98tlmNm~          1
# 20   from United States  Nk4AAOSwYvRmB7b7          1
# 21   from United States  kl0AAOSwHJhj8s1i          1
# 22   from United States  xtsAAOSwe75fJ1Up          1
# 23   from United States  OngAAOSwDuZmFHYs          1
# 24       from Australia  ltcAAOSwh-RlLaAW          1
# 26   from United States  Lp4AAOSwWGdf~nta          1
# 27     from Netherlands  CocAAOSw235lyOA3          1
# 29   from United States  B68AAOSwq-Reow0c          1
# 30   from United States  ZzMAAOSwohZmG294          1
# 31   from United States  15QAAOSwAWBmGGvl          1
# 32   from United States  2MsAAOSw55Fl66O2          1
# 33   from United States  yHsAAOSw0sJl4FlY          1
# 35   from United States  1k0AAOSwQhJmDDxZ          1
# 36   from United States  rX0AAOSwDCRl~jz6          1
# 37   from United States  dv0AAOSwGydl7xJn          1
# 38   from United States  cY4AAOSwym1lg0mQ          1
# 39   from United States  9f4AAOSwkBhmDiuc          1
# 40   from United States  Ed0AAOSwsJBi23wR          1
# 41   from United States  BykAAOSwnepmBYTb          1
# 42   from United States  8lEAAOSwf39mEY7b          1
# 48   from United States  XqYAAOSwu-tenwyI          1
# 50   from United States  m~QAAOSw-rVfwOUJ          1
# 56   from United States  Rh0AAOSwEYFlDHaw          1
# 58   from United States  2e8AAOSwwpVjQF5~          1
# 62   from United States  MS8AAOSwoHNlXlpp          1
# 64   from United States  v0IAAOSw61Vl~K18          1
# 67   from United States  mx8AAOSwAQllTWt2          1
# 70   from United States  leEAAOSwtN5lDHaz          1
# 76   from United States  BSwAAOSwH0dl-ifv          1
# 77   from United States  ZTIAAOSw68Vlxacy          1
# 82   from United States  Vi8AAOSwKhpdxlYw          1
# 89   from United States  d58AAOSwpB9lqDnw          1
# 91   from United States  Fo0AAOSwqStendYW          1
# 100  from United States  NeUAAOSwjolkQNpt          1
# 103  from United States  5fgAAOSwZiZlKq9o          1
# 105  from United States  9ygAAOSwNotl34Ru          1
# 116  from United States  NxgAAOSwTudl1SdC          1
# 117  from United States  vZkAAOSwnX5l2t~B          1
# 121  from United States  StQAAOSwoupl1hTg          1
# 122  from United States  uTcAAOSwQqNlDHag          1
# 129  from United States  ~YkAAOSw3-ZkIMN2          1
# 131  from United States  FBMAAOSwuZtjXMQi          1
# 139  from United States  nccAAOSwuntlDHal          1
# 146  from United States  VIYAAOSwk3Blg5UF          1
# 153  from United States  uS0AAOSwNXtlwO32          1

# %%
df.to_csv("C:/Users/marco/Downloads/gest.csv", index = False)

# %%
import pandas as pd
df = pd.read_excel("C:/Users/marco/Downloads/ebay_sales_got_2024-04-23.xlsx")
df.rename(columns = {'img_link': 'galleryURL'}, inplace = True)
df['sale_data'] = pd.to_datetime(df['sale_data']).dt.strftime('%Y-%m-%d')
df.head(3)
# Out:
#    Unnamed: 0  Image                                         galleryURL  \
# 0          33    NaN  https://i.ebayimg.com/thumbs/images/g/8lEAAOSw...
# 1          65    NaN  https://i.ebayimg.com/thumbs/images/g/BSwAAOSw...
# 2          22    NaN  https://i.ebayimg.com/thumbs/images/g/ZzMAAOSw...
#
#                                                title  price  reduced  \
# 0  George R.R. Martin: A GAME OF THRONES **HC/DJ ...   90.0        0
# 1  1st Ed - A GAME of THRONES George R.R. Martin ...  185.0        0
# 2  George R.R. Martin. A GAME OF THRONES. Bantam,...  150.0        0
#
#           seller  seller_rating  seller_sales   sale_data           country  \
# 0  marvonbruen_0              0             0  2024-04-06  No country found
# 1      vacantjay              0             0  2024-03-20  No country found
# 2      lagarm-35              0             0  2024-04-14  No country found
#
#        condition    sub_edition  edition_id  is_edition  \
# 0  Not Available  Not Available           1        True
# 1  Not Available  Not Available           1        True
# 2  Not Available  Not Available           1        True
#
#    is_edition_probability      signed  is_signed_probability  \
# 0                0.911785  Not Signed                      0
# 1                0.885908  Not Signed                      0
# 2                0.778444  Not Signed                      0
#
#    condition_probability  correct
# 0                      0     True
# 1                      0     True
# 2                      0     True

# %%
from load_file import EbaySalesLoad

# %%
EbaySalesLoad(df, env='development').load_ml_books()
# Out:
# Successfully sent data.
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/BSwAAOSwH0dl-ifv/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/BSwAAOSwH0dl-ifv/s-l300.jpg', True, 0.8859084248542786, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/ZzMAAOSwohZmG294/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/ZzMAAOSwohZmG294/s-l300.jpg', True, 0.7784435153007507, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/tnUAAOSwXNdmJENs/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/tnUAAOSwXNdmJENs/s-l300.jpg', True, 0.7584586143493652, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/ZTIAAOSw68Vlxacy/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/ZTIAAOSw68Vlxacy/s-l300.jpg', True, 0.702453076839447, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/rScAAOSwJE1mGuhJ/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/rScAAOSwJE1mGuhJ/s-l300.jpg', True, 0.6655570864677429, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/naUAAOSwe7NmAHM3/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/naUAAOSwe7NmAHM3/s-l300.jpg', True, 0.6576783657073975, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# Failed to send data. Status code: 400, Response: {"detail":"(sqlalchemy.dialects.postgresql.asyncpg.IntegrityError) <class 'asyncpg.exceptions.UniqueViolationError'>: un valore chiave duplicato viola il vincolo univoco \"ml_books_pkey\"\nDETAIL:  La chiave (edition_id, img_link)=(1, https://i.ebayimg.com/thumbs/images/g/NeUAAOSwjolkQNpt/s-l300.jpg) esiste già.\n[SQL: INSERT INTO bbourse.ml_books (edition_id, img_link, prediction, prediction_probability, label) VALUES (%s, %s, %s, %s, %s)]\n[parameters: (1, 'https://i.ebayimg.com/thumbs/images/g/NeUAAOSwjolkQNpt/s-l300.jpg', True, 0.6538731455802917, True)]\n(Background on this error at: https://sqlalche.me/e/14/gkpj)"}
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] Impossibile stabilire la connessione. Rifiuto persistente del computer di destinazione
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 EbaySalesLoad(df, env='development').load_ml_books()
#
# File c:\Users\marco\Desktop\Projects\bbourse\ml-pipeline\ml-pipeline\load_file.py:71, in LoadFile.load_ml_books(self)
#      70 def load_ml_books(self):
# ---> 71     prepare_and_send_data(self.df, "ml_book", env = self.env)
#
# File c:\Users\marco\Desktop\Projects\bbourse\ml-pipeline\ml-pipeline\load_file.py:40, in prepare_and_send_data(df, load_type, env)
#      37         payload[key] = value
#      39 # print(json.dumps(payload, indent=2))
# ---> 40 response = requests.post(url, json=payload, headers=headers)
#      42 if response.status_code != 200:
#      43     print(
#      44         f"Failed to send data. Status code: {response.status_code}, Response: {response.text}"
#      45     )
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#     510 except BrokenPipeError:
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     398 for header, value in headers.items():
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#     403 if chunks is not None:
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#     241         self._has_connected_to_proxy = True
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\socket.py:500, in socket.close(self)
#     496 def _real_close(self, _ss=_socket.socket):
#     497     # This function should not reference any globals. See issue #808164.
#     498     _ss.close(self)
# --> 500 def close(self):
#     501     # This function should not reference any globals. See issue #808164.
#     502     self._closed = True
#     503     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
df = df[df['correct'] == True]
df
prepare_and_send_data(df, "ebay_sales", env = 'development' )
# Out:
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/8lEAAOSwf39mEY7b/s-l300.jpg",
#   "title": "George R.R. Martin: A GAME OF THRONES **HC/DJ First Edition DAMAGED SEE PICS",
#   "price": 90.0,
#   "reduced": 0,
#   "seller": "marvonbruen_0",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-06T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/BSwAAOSwH0dl-ifv/s-l300.jpg",
#   "title": "1st Ed - A GAME of THRONES George R.R. Martin HARDCOVER Excellent Condition",
#   "price": 185.0,
#   "reduced": 0,
#   "seller": "vacantjay",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-20T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/ZzMAAOSwohZmG294/s-l300.jpg",
#   "title": "George R.R. Martin. A GAME OF THRONES. Bantam, 1996. 1st HC/DW.",
#   "price": 150.0,
#   "reduced": 0,
#   "seller": "lagarm-35",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-14T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/tnUAAOSwXNdmJENs/s-l300.jpg",
#   "title": "A Game Of Thrones 1996 George RR Martin 1st Ed 1st Print Hardcover Book Metallic",
#   "price": 350.0,
#   "reduced": 0,
#   "seller": "2211brent",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-21T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/ZTIAAOSw68Vlxacy/s-l300.jpg",
#   "title": "A Game of Thrones ~ GEORGE R. R. MARTIN ~ First Edition 1996 ~ 1st Printing RR",
#   "price": 495.0,
#   "reduced": 0,
#   "seller": "krakow1",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-19T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/rScAAOSwJE1mGuhJ/s-l300.jpg",
#   "title": "George R.R. Martin: A GAME OF THRONES **HC/DJ First Edition DAMAGED SEE PICS",
#   "price": 77.69,
#   "reduced": 0,
#   "seller": "jimmy682011",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-20T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/naUAAOSwe7NmAHM3/s-l300.jpg",
#   "title": "George R.R. Martin. A GAME OF THRONES. Bantam, 1996. 1st HC/DW.",
#   "price": 350.0,
#   "reduced": 0,
#   "seller": "larmojovi",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-21T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/NeUAAOSwjolkQNpt/s-l300.jpg",
#   "title": "1st Ed - A GAME of THRONES George R.R. Martin HARDCOVER excellent",
#   "price": 419.3,
#   "reduced": 0,
#   "seller": "the_vintage_viking",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-06T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/9ygAAOSwNotl34Ru/s-l300.jpg",
#   "title": "A Game Of Thrones-George R. R. Martin-FIRST EDITION Hardcover With Dust jacket",
#   "price": 51.0,
#   "reduced": 0,
#   "seller": "coolpapasmurf",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-05T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/d58AAOSwpB9lqDnw/s-l300.jpg",
#   "title": "A GAME OF THRONES *SIGNED* 1ST/1ST First Edition & PRINTING GEORGE R.R. MARTIN",
#   "price": 699.0,
#   "reduced": 0,
#   "seller": "martinsscifisociety",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-11T00:00:00",
#   "country": "No country found",
#   "signed": "Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/gK0AAOSw3ctl5ez1/s-l300.jpg",
#   "title": "A Game Of Thrones George R. R. Martin-First Edition Hardcover with Dust Jacket",
#   "price": 69.99,
#   "reduced": 0,
#   "seller": "sarsiuppius5",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-05T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/BykAAOSwnepmBYTb/s-l300.jpg",
#   "title": "George R.R. Martin: A GAME OF THRONES Bantam Hardcover 1996 Metallic 1st 1st",
#   "price": 405.0,
#   "reduced": 0,
#   "seller": "myclosetofrandomness",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-07T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/LoYAAOSwqdBmFWGa/s-l300.jpg",
#   "title": "George R R Martin / A Game of Thrones Signed 1st Edition 1996 #2312118",
#   "price": 500.0,
#   "reduced": 0,
#   "seller": "bookbid",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-20T00:00:00",
#   "country": "No country found",
#   "signed": "Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/v0IAAOSw61Vl~K18/s-l300.jpg",
#   "title": "George R.R. Martin: A GAME OF THRONES **HC/DJ First Edition, First Printing",
#   "price": 245.5,
#   "reduced": 0,
#   "seller": "towhsl-0",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-03-28T00:00:00",
#   "country": "No country found",
#   "signed": "Not Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/dv0AAOSwGydl7xJn/s-l300.jpg",
#   "title": "SIGNED NOTE A Game of Thrones by George R. R. Martin 1st Edition/ 1st Print 1996",
#   "price": 500.0,
#   "reduced": 0,
#   "seller": "extrashelfspace",
#   "seller_rating": 0.0,
#   "seller_sales": 0.0,
#   "sale_data": "2024-04-10T00:00:00",
#   "country": "No country found",
#   "signed": "Signed",
#   "condition": "Not Available",
#   "sub_edition": "Not Available"
# }
# Successfully sent data.
