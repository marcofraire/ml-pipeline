# %%
import pandas as pd
df = pd.read_excel("output_2024-04-09.xlsx")
df.head(3)
# Out:
#    img        itemId                                              title  \
# 0  NaN  335337874232  A Game of Thrones - George R. R. Martin (HC, 1...
# 1  NaN  124988572940  A GAME OF THRONES (George R. R. Martin/1st US/...
# 2  NaN  134644726895  A Game of Thrones - George RR Martin (Hardcove...
#
#                                           galleryURL  \
# 0  https://i.ebayimg.com/thumbs/images/g/8AYAAOSw...
# 1  https://i.ebayimg.com/thumbs/images/g/46oAAOSw...
# 2  https://i.ebayimg.com/thumbs/images/g/Iw4AAOSw...
#
#                                          viewItemURL   listing_type  \
# 0  https://www.ebay.com/itm/Game-Thrones-George-R...  Non Available
# 1  https://www.ebay.com/itm/GAME-THRONES-George-R...  Non Available
# 2  https://www.ebay.com/itm/Game-Thrones-George-R...  Non Available
#
#           seller  seller_rating  seller_sales        country   price  \
# 0  Non Available              0             0  Non Available  1050.0
# ...

# %%
from ml_pipeline import prepare_and_send_data

# %%
# prepare_and_send_data(df[44:46], "ml_book", env = 'development' )
# Out:
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/0vMAAOSw89lkuOYw/s-l140.jpg",
#   "label": false
# }
# Successfully sent data.
# {
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/PmcAAOSwNSpl34TP/s-l140.jpg",
#   "label": false
# }
# Successfully sent data.

# %%
prepare_and_send_data(df[44:46], "ebay_listings", env = 'development' )
# Out:
# {
#   "ebay_link": "https://www.ebay.com/itm/Sarah-J-Maas-Books-Throne-Glass-Court-Thorns-and-Roses-Series-Variation-/253585499607?var=556121595228",
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/0vMAAOSw89lkuOYw/s-l140.jpg",
#   "title": "Sarah J.Maas Books Throne Of Glass, Court of Thorns and Roses Series | Variation",
#   "price": 75.87,
#   "listing_type": "Non Available",
#   "seller": "Non Available",
#   "seller_rating": 0,
#   "seller_sales": 0,
#   "country": "Non Available",
#   "signed": "Not Signed",
#   "condition": "Non Available",
#   "sub_edition": "Non Available"
# }
# Successfully sent data.
# {
#   "ebay_link": "https://www.ebay.com/itm/Game-Thrones-1st-Edition-1996-Jon-Snow-Variant-HC-Acceptable-Edge-Spotting-/196269159160",
#   "edition_id": 1,
#   "img_link": "https://i.ebayimg.com/thumbs/images/g/PmcAAOSwNSpl34TP/s-l140.jpg",
#   "title": "A Game Of Thrones-1st Edition-1996- Jon Snow Variant HC-Acceptable Edge Spotting",
# ...
